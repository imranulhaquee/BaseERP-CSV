# %% [markdown]
# <p style="font-size:2.2em; color:white; padding:25px; border-bottom: 5px solid #ffb701; background:#143157;">
#     Show Trial Balance - <span style="font-size:.75em; color: #11a1f5;"> from excel file </span></p>
# Read data from csv in Pandas

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:,.0f}'.format
pd.set_option('display.max_columns', 85) # set Jupeter note book to dispay 85 columns

# %% [markdown]
# <p style="font-size:1.5em; color:white; padding:5px; border-bottom: 3px solid orange; background: #3c5c75; margin: 25px 0 -7px 0;">
# Step 1 - Read Excel files </p>

# %%
###---- Read Employee master File ------------------------------------------
df = pd.read_csv("Data/C1_Gl/Tb/Tb.csv",encoding='unicode_escape').fillna('')

# %% [markdown]
# <p style="font-size:1.5em; color:white; padding:5px; border-bottom: 3px solid orange; background: #3c5c75; margin: 25px 0 -7px 0;">
# Step 2 - Convert into Json </p>

# %%
### Convert Data into Json Dictionary (can be access by JavaScript) .........
Data = df.to_dict(orient="records")

# %% [markdown]
# <p style="font-family:Calibri; font-size:1.75em; color:white; padding:5px 5px; text-align: left; height:50px;">
# </p>

# %% [markdown]
# <p style="font-size:2.2em; color:white; padding:25px; border-bottom: 5px solid #ffb701; background:#143157;">
#     Add New - <span style="font-size:.75em; color: #11a1f5;"> GL Account </span></p>
# Read data from csv in Pandas

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:,.0f}'.format
pd.set_option('display.max_columns', 85) # set Jupeter note book to dispay 85 columns

# %% [markdown]
# <p style="font-size:1.5em; color:white; padding:5px; border-bottom: 3px solid orange; background: #3c5c75; margin: 25px 0 -7px 0;">
# Step 1 - Read Excel files </p>

# %%
###---- Read Employee master File ------------------------------------------
df = pd.read_excel("Data/B1_Setup/CoA/CoA Level.xlsx").fillna(0)

# %%
Data = df.values.tolist()
Data
# Out:
# [['1-Assets',
#   '1-Non Current Assets',
#   '1-Property and Equipment',
#   '1-Land And Land Improvements',
#   1500],
#  ['1-Assets',
#   '1-Non Current Assets',
#   '1-Property and Equipment',
#   '2-Buildings, Structures And Improvements',
#   1750],
#  ['1-Assets',
#   '1-Non Current Assets',
#   '1-Property and Equipment',
#   '3-Machinery And Equipment',
#   2250],
#  ['1-Assets',
#   '1-Non Current Assets',
#   '1-Property and Equipment',
#   '4-Furniture And Fixtures',
#   3511],
#  ['1-Assets',
#   '1-Non Current Assets',
#   '1-Property and Equipment',
#   '5-Right Of Use Assets (Classified As PP&E)',
#   1564],
#  ['1-Assets',
#   '1-Non Current Assets',
#   '1-Property and Equipment',
#   '6-Construction In Progress',
#   1565],
#  ['1-Assets',
#   '1-Non Current Assets',
#   '2-Intangible Assets',
#   '1-Software',
#   886],
#  ['1-Assets',
#   '1-Non Current Assets',
#   '2-Intangible Assets',
#   '2-Copy Rights',
#   156],
#  ['1-Assets',
#   '1-Non Current Assets',
#   '3-Investment in subsidiary',
#   '1-Investments',
#   13351],
#  ['1-Assets',
#   '2-Current Assets',
#   '1-Inventories',
#   '1-Inventory in Warehouse',
#   1233],
#  ['1-Assets', '2-Current Assets', '1-Inventories', '1-Goods in Transit', 1265],
#  ['1-Assets',
#   '2-Current Assets',
#   '1-Inventories',
#   '1-Inventory Provision',
#   -2153],
#  ['1-Assets',
#   '2-Current Assets',
#   '2-Due From Related Parties',
#   '1-Due From Related Parties',
#   1568],
#  ['1-Assets',
#   '2-Current Assets',
#   '3-Trade Receivables',
#   '1-Trade Receivables',
#   156548],
#  ['1-Assets',
#   '2-Current Assets',
#   '3-Trade Receivables',
#   '2-Receivable Provision',
#   -15651],
#  ['1-Assets',
#   '2-Current Assets',
#   '4-Other Receivables',
#   '1-Prepayments',
#   1565],
#  ['1-Assets', '2-Current Assets', '4-Other Receivables', '2-Advances', 1586],
#  ['1-Assets', '2-Current Assets', '4-Other Receivables', '3-Deposits', 15673],
#  ['1-Assets',
#   '2-Current Assets',
#   '5-Other Financial Assets',
#   '1-Deposits with Bank',
#   15654],
#  ['1-Assets',
#   '2-Current Assets',
#   '6-Cash and Cash Equivalents',
#   '1-Cash in Hand',
#   8641],
#  ['1-Assets',
#   '2-Current Assets',
#   '6-Cash and Cash Equivalents',
#   '2-Cash at Bank',
#   14565],
#  ['2-Equity', '1-Equity', '1-Share Capital', '1-Share Capital', -15646],
#  ['2-Equity', '1-Equity', '2-Statutory Reserve', '1-Statutory Reserve', -1567],
#  ['2-Equity',
#   '1-Equity',
#   '3-Capital Contribution ',
#   '1-Capital Contribution ',
#   -1657],
#  ['2-Equity', '1-Equity', '4-Retained Earnings', '1-Retained Earnings', 0],
#  ['2-Equity',
#   '1-Equity',
#   '5-Profit/Loss for the year',
#   '1-Profit/Loss for the year',
#   -8987],
#  ['3-Liabilities',
#   '1-Non Current Liabilities',
#   "1-Employees' End of Service Indemnity",
#   '1-EOSI',
#   -1656],
#  ['3-Liabilities',
#   '2-Current Liabilities',
#   '1-Trade Payables',
#   '1-Suppliers',
#   -7468],
#  ['3-Liabilities',
#   '2-Current Liabilities',
#   '1-Trade Payables',
#   '2-Vendors',
#   -15651],
#  ['3-Liabilities',
#   '2-Current Liabilities',
#   '2-Other Payables',
#   '1-Accruals',
#   -8456],
#  ['3-Liabilities',
#   '2-Current Liabilities',
#   '2-Other Payables',
#   '2-Other Payables',
#   -1563],
#  ['3-Liabilities',
#   '2-Current Liabilities',
#   '3-Liabilities against subject to finance lease',
#   '1-Finance Lease',
#   -786],
#  ['3-Liabilities',
#   '2-Current Liabilities',
#   '4-Bank Borrowings',
#   '1-OverDraft',
#   -16144],
#  ['3-Liabilities',
#   '2-Current Liabilities',
#   '4-Bank Borrowings',
#   '2-L/C',
#   -4586],
#  ['3-Liabilities',
#   '2-Current Liabilities',
#   '4-Bank Borrowings',
#   '3-Cheque Discounting',
#   -7465],
#  ['3-Liabilities',
#   '2-Current Liabilities',
#   '5-Due to related parties',
#   '1-Due to related parties',
#   -15648],
#  ['4-Profit and Loss', '1-Sales', '1-Medical-Sals', '1-Medical-Sals', -556555],
#  ['4-Profit and Loss',
#   '1-Sales',
#   '2-Equipment-Sales',
#   '1-Equipment-Sales',
#   -315425],
#  ['4-Profit and Loss',
#   '2-Cost of Sales',
#   '1-Medical-Cost',
#   '1-Medical-Cost',
#   356411],
#  ['4-Profit and Loss',
#   '2-Cost of Sales',
#   '2-Equipment-Cost',
#   '1-Equipment-Cost',
#   245651],
#  ['4-Profit and Loss',
#   '3-Direct Expenses',
#   '1-Salaries and Related Cost - D',
#   '1-Salaries and Related Cost - D',
#   56841],
#  ['4-Profit and Loss',
#   '3-Direct Expenses',
#   '2-Communications - D',
#   '1-Communications - D',
#   1565],
#  ['4-Profit and Loss',
#   '3-Direct Expenses',
#   '3-Sales Commissionv - D',
#   '1-Sales Commissionv - D',
#   8746],
#  ['4-Profit and Loss',
#   '3-Direct Expenses',
#   '4-Gratuity Provision - D',
#   '1-Gratuity Provision - D',
#   1565],
#  ['4-Profit and Loss',
#   '3-Direct Expenses',
#   '5-Leave salaries &air tickets - D',
#   '1-Leave salaries &air tickets - D',
#   9658],
#  ['4-Profit and Loss',
#   '3-Direct Expenses',
#   '6-Selling and business promotion - D',
#   '1-Selling and business promotion - D',
#   4565],
#  ['4-Profit and Loss',
#   '4-Indirect Expenses',
#   '1-Salaries and Related Cost',
#   '1-Salaries and Related Cost',
#   4565],
#  ['4-Profit and Loss', '4-Indirect Expenses', '2-Bonus', '1-Bonus', 1587],
#  ['4-Profit and Loss',
#   '4-Indirect Expenses',
#   '3-Gratuity Provision',
#   '1-Gratuity Provision',
#   2452],
#  ['4-Profit and Loss',
#   '4-Indirect Expenses',
#   '4-Leave Salaries and Tickets',
#   '1-Leave Salaries and Tickets',
#   3254],
#  ['4-Profit and Loss',
#   '4-Indirect Expenses',
#   '5-Legal, license and professional fee',
#   '1-Legal, license and professional fee',
#   6654],
#  ['4-Profit and Loss',
#   '4-Indirect Expenses',
#   '6-Travelling and Vehicle maintenance',
#   '1-Travelling and Vehicle maintenance',
#   4598],
#  ['4-Profit and Loss', '4-Indirect Expenses', '7-Rent', '1-Rent', 6871],
#  ['4-Profit and Loss',
#   '4-Indirect Expenses',
#   '8-Office maintenance',
#   '1-Office maintenance',
#   9879],
#  ['4-Profit and Loss',
#   '4-Indirect Expenses',
#   '9-Bad debts',
#   '1-Bad debts',
#   1565],
#  ['4-Profit and Loss',
#   '4-Indirect Expenses',
#   '10-Insurance',
#   '1-Insurance',
#   1326],
#  ['4-Profit and Loss',
#   '4-Indirect Expenses',
#   '11-Provision for slow moving inventories',
#   '1-Provision for slow moving inventories',
#   2165],
#  ['4-Profit and Loss',
#   '4-Indirect Expenses',
#   '12-Communications',
#   '1-Communications',
#   1565],
#  ['4-Profit and Loss',
#   '4-Indirect Expenses',
#   '13-Bank charges',
#   '1-Bank charges',
#   3218],
#  ['4-Profit and Loss',
#   '4-Indirect Expenses',
#   '14-Printing and stationery',
#   '1-Printing and stationery',
#   1568],
#  ['4-Profit and Loss', '4-Indirect Expenses', '15-Others', '1-Others', 6221],
#  ['4-Profit and Loss',
#   '5-Other Expenses',
#   '1-Other Expenses',
#   '1-Other Expenses',
#   6521],
#  ['4-Profit and Loss',
#   '6-Other Income',
#   '1-Other Income',
#   '1-Other Income',
#   -1548],
#  ['4-Profit and Loss',
#   '7-Depreciation and amortiaztion',
#   '1-Depreciation and amortiaztion',
#   '1-Depreciation and amortiaztion',
#   3215],
#  ['4-Profit and Loss',
#   '8-Finance Cost',
#   '1-Finance Cost',
#   '1-Finance Cost',
#   1555]]

# %%
Data_6=[]
for i in range(df.shape[0]):
        temp=df.iloc[i]
        Data_6.append(dict(temp))
Data_6
# Out:
# [{'C1': '1-Assets',
#   'C2': '1-Non Current Assets',
#   'C3': '1-Property and Equipment',
#   'C4': '1-Land And Land Improvements',
#   'Amount': 1500},
#  {'C1': '1-Assets',
#   'C2': '1-Non Current Assets',
#   'C3': '1-Property and Equipment',
#   'C4': '2-Buildings, Structures And Improvements',
#   'Amount': 1750},
#  {'C1': '1-Assets',
#   'C2': '1-Non Current Assets',
#   'C3': '1-Property and Equipment',
#   'C4': '3-Machinery And Equipment',
#   'Amount': 2250},
#  {'C1': '1-Assets',
#   'C2': '1-Non Current Assets',
#   'C3': '1-Property and Equipment',
#   'C4': '4-Furniture And Fixtures',
#   'Amount': 3511},
#  {'C1': '1-Assets',
#   'C2': '1-Non Current Assets',
#   'C3': '1-Property and Equipment',
#   'C4': '5-Right Of Use Assets (Classified As PP&E)',
#   'Amount': 1564},
#  {'C1': '1-Assets',
#   'C2': '1-Non Current Assets',
#   'C3': '1-Property and Equipment',
#   'C4': '6-Construction In Progress',
#   'Amount': 1565},
#  {'C1': '1-Assets',
#   'C2': '1-Non Current Assets',
#   'C3': '2-Intangible Assets',
#   'C4': '1-Software',
#   'Amount': 886},
#  {'C1': '1-Assets',
#   'C2': '1-Non Current Assets',
#   'C3': '2-Intangible Assets',
#   'C4': '2-Copy Rights',
#   'Amount': 156},
#  {'C1': '1-Assets',
#   'C2': '1-Non Current Assets',
#   'C3': '3-Investment in subsidiary',
#   'C4': '1-Investments',
#   'Amount': 13351},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '1-Inventories',
#   'C4': '1-Inventory in Warehouse',
#   'Amount': 1233},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '1-Inventories',
#   'C4': '1-Goods in Transit',
#   'Amount': 1265},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '1-Inventories',
#   'C4': '1-Inventory Provision',
#   'Amount': -2153},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '2-Due From Related Parties',
#   'C4': '1-Due From Related Parties',
#   'Amount': 1568},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '3-Trade Receivables',
#   'C4': '1-Trade Receivables',
#   'Amount': 156548},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '3-Trade Receivables',
#   'C4': '2-Receivable Provision',
#   'Amount': -15651},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '4-Other Receivables',
#   'C4': '1-Prepayments',
#   'Amount': 1565},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '4-Other Receivables',
#   'C4': '2-Advances',
#   'Amount': 1586},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '4-Other Receivables',
#   'C4': '3-Deposits',
#   'Amount': 15673},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '5-Other Financial Assets',
#   'C4': '1-Deposits with Bank',
#   'Amount': 15654},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '6-Cash and Cash Equivalents',
#   'C4': '1-Cash in Hand',
#   'Amount': 8641},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '6-Cash and Cash Equivalents',
#   'C4': '2-Cash at Bank',
#   'Amount': 14565},
#  {'C1': '2-Equity',
#   'C2': '1-Equity',
#   'C3': '1-Share Capital',
#   'C4': '1-Share Capital',
#   'Amount': -15646},
#  {'C1': '2-Equity',
#   'C2': '1-Equity',
#   'C3': '2-Statutory Reserve',
#   'C4': '1-Statutory Reserve',
#   'Amount': -1567},
#  {'C1': '2-Equity',
#   'C2': '1-Equity',
#   'C3': '3-Capital Contribution ',
#   'C4': '1-Capital Contribution ',
#   'Amount': -1657},
#  {'C1': '2-Equity',
#   'C2': '1-Equity',
#   'C3': '4-Retained Earnings',
#   'C4': '1-Retained Earnings',
#   'Amount': 0},
#  {'C1': '2-Equity',
#   'C2': '1-Equity',
#   'C3': '5-Profit/Loss for the year',
#   'C4': '1-Profit/Loss for the year',
#   'Amount': -8987},
#  {'C1': '3-Liabilities',
#   'C2': '1-Non Current Liabilities',
#   'C3': "1-Employees' End of Service Indemnity",
#   'C4': '1-EOSI',
#   'Amount': -1656},
#  {'C1': '3-Liabilities',
#   'C2': '2-Current Liabilities',
#   'C3': '1-Trade Payables',
#   'C4': '1-Suppliers',
#   'Amount': -7468},
#  {'C1': '3-Liabilities',
#   'C2': '2-Current Liabilities',
#   'C3': '1-Trade Payables',
#   'C4': '2-Vendors',
#   'Amount': -15651},
#  {'C1': '3-Liabilities',
#   'C2': '2-Current Liabilities',
#   'C3': '2-Other Payables',
#   'C4': '1-Accruals',
#   'Amount': -8456},
#  {'C1': '3-Liabilities',
#   'C2': '2-Current Liabilities',
#   'C3': '2-Other Payables',
#   'C4': '2-Other Payables',
#   'Amount': -1563},
#  {'C1': '3-Liabilities',
#   'C2': '2-Current Liabilities',
#   'C3': '3-Liabilities against subject to finance lease',
#   'C4': '1-Finance Lease',
#   'Amount': -786},
#  {'C1': '3-Liabilities',
#   'C2': '2-Current Liabilities',
#   'C3': '4-Bank Borrowings',
#   'C4': '1-OverDraft',
#   'Amount': -16144},
#  {'C1': '3-Liabilities',
#   'C2': '2-Current Liabilities',
#   'C3': '4-Bank Borrowings',
#   'C4': '2-L/C',
#   'Amount': -4586},
#  {'C1': '3-Liabilities',
#   'C2': '2-Current Liabilities',
#   'C3': '4-Bank Borrowings',
#   'C4': '3-Cheque Discounting',
#   'Amount': -7465},
#  {'C1': '3-Liabilities',
#   'C2': '2-Current Liabilities',
#   'C3': '5-Due to related parties',
#   'C4': '1-Due to related parties',
#   'Amount': -15648},
#  {'C1': '4-Profit and Loss',
#   'C2': '1-Sales',
#   'C3': '1-Medical-Sals',
#   'C4': '1-Medical-Sals',
#   'Amount': -556555},
#  {'C1': '4-Profit and Loss',
#   'C2': '1-Sales',
#   'C3': '2-Equipment-Sales',
#   'C4': '1-Equipment-Sales',
#   'Amount': -315425},
#  {'C1': '4-Profit and Loss',
#   'C2': '2-Cost of Sales',
#   'C3': '1-Medical-Cost',
#   'C4': '1-Medical-Cost',
#   'Amount': 356411},
#  {'C1': '4-Profit and Loss',
#   'C2': '2-Cost of Sales',
#   'C3': '2-Equipment-Cost',
#   'C4': '1-Equipment-Cost',
#   'Amount': 245651},
#  {'C1': '4-Profit and Loss',
#   'C2': '3-Direct Expenses',
#   'C3': '1-Salaries and Related Cost - D',
#   'C4': '1-Salaries and Related Cost - D',
#   'Amount': 56841},
#  {'C1': '4-Profit and Loss',
#   'C2': '3-Direct Expenses',
#   'C3': '2-Communications - D',
#   'C4': '1-Communications - D',
#   'Amount': 1565},
#  {'C1': '4-Profit and Loss',
#   'C2': '3-Direct Expenses',
#   'C3': '3-Sales Commissionv - D',
#   'C4': '1-Sales Commissionv - D',
#   'Amount': 8746},
#  {'C1': '4-Profit and Loss',
#   'C2': '3-Direct Expenses',
#   'C3': '4-Gratuity Provision - D',
#   'C4': '1-Gratuity Provision - D',
#   'Amount': 1565},
#  {'C1': '4-Profit and Loss',
#   'C2': '3-Direct Expenses',
#   'C3': '5-Leave salaries &air tickets - D',
#   'C4': '1-Leave salaries &air tickets - D',
#   'Amount': 9658},
#  {'C1': '4-Profit and Loss',
#   'C2': '3-Direct Expenses',
#   'C3': '6-Selling and business promotion - D',
#   'C4': '1-Selling and business promotion - D',
#   'Amount': 4565},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '1-Salaries and Related Cost',
#   'C4': '1-Salaries and Related Cost',
#   'Amount': 4565},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '2-Bonus',
#   'C4': '1-Bonus',
#   'Amount': 1587},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '3-Gratuity Provision',
#   'C4': '1-Gratuity Provision',
#   'Amount': 2452},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '4-Leave Salaries and Tickets',
#   'C4': '1-Leave Salaries and Tickets',
#   'Amount': 3254},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '5-Legal, license and professional fee',
#   'C4': '1-Legal, license and professional fee',
#   'Amount': 6654},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '6-Travelling and Vehicle maintenance',
#   'C4': '1-Travelling and Vehicle maintenance',
#   'Amount': 4598},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '7-Rent',
#   'C4': '1-Rent',
#   'Amount': 6871},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '8-Office maintenance',
#   'C4': '1-Office maintenance',
#   'Amount': 9879},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '9-Bad debts',
#   'C4': '1-Bad debts',
#   'Amount': 1565},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '10-Insurance',
#   'C4': '1-Insurance',
#   'Amount': 1326},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '11-Provision for slow moving inventories',
#   'C4': '1-Provision for slow moving inventories',
#   'Amount': 2165},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '12-Communications',
#   'C4': '1-Communications',
#   'Amount': 1565},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '13-Bank charges',
#   'C4': '1-Bank charges',
#   'Amount': 3218},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '14-Printing and stationery',
#   'C4': '1-Printing and stationery',
#   'Amount': 1568},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '15-Others',
#   'C4': '1-Others',
#   'Amount': 6221},
#  {'C1': '4-Profit and Loss',
#   'C2': '5-Other Expenses',
#   'C3': '1-Other Expenses',
#   'C4': '1-Other Expenses',
#   'Amount': 6521},
#  {'C1': '4-Profit and Loss',
#   'C2': '6-Other Income',
#   'C3': '1-Other Income',
#   'C4': '1-Other Income',
#   'Amount': -1548},
#  {'C1': '4-Profit and Loss',
#   'C2': '7-Depreciation and amortiaztion',
#   'C3': '1-Depreciation and amortiaztion',
#   'C4': '1-Depreciation and amortiaztion',
#   'Amount': 3215},
#  {'C1': '4-Profit and Loss',
#   'C2': '8-Finance Cost',
#   'C3': '1-Finance Cost',
#   'C4': '1-Finance Cost',
#   'Amount': 1555}]

# %% [markdown]
# <p style="font-size:1.5em; color:white; padding:5px; border-bottom: 3px solid orange; background: #3c5c75; margin: 25px 0 -7px 0;">
# Step 2 - Convert into Json </p>

# %%
### Convert Data into Json Dictionary (can be access by JavaScript) .........
Data = df.to_dict(orient="records")

# %%
Data
# Out:
# [{'C1': '1-Assets',
#   'C2': '1-Non Current Assets',
#   'C3': '1-Property and Equipment',
#   'C4': '1-Land And Land Improvements',
#   'Amount': 1500},
#  {'C1': '1-Assets',
#   'C2': '1-Non Current Assets',
#   'C3': '1-Property and Equipment',
#   'C4': '2-Buildings, Structures And Improvements',
#   'Amount': 1750},
#  {'C1': '1-Assets',
#   'C2': '1-Non Current Assets',
#   'C3': '1-Property and Equipment',
#   'C4': '3-Machinery And Equipment',
#   'Amount': 2250},
#  {'C1': '1-Assets',
#   'C2': '1-Non Current Assets',
#   'C3': '1-Property and Equipment',
#   'C4': '4-Furniture And Fixtures',
#   'Amount': 3511},
#  {'C1': '1-Assets',
#   'C2': '1-Non Current Assets',
#   'C3': '1-Property and Equipment',
#   'C4': '5-Right Of Use Assets (Classified As PP&E)',
#   'Amount': 1564},
#  {'C1': '1-Assets',
#   'C2': '1-Non Current Assets',
#   'C3': '1-Property and Equipment',
#   'C4': '6-Construction In Progress',
#   'Amount': 1565},
#  {'C1': '1-Assets',
#   'C2': '1-Non Current Assets',
#   'C3': '2-Intangible Assets',
#   'C4': '1-Software',
#   'Amount': 886},
#  {'C1': '1-Assets',
#   'C2': '1-Non Current Assets',
#   'C3': '2-Intangible Assets',
#   'C4': '2-Copy Rights',
#   'Amount': 156},
#  {'C1': '1-Assets',
#   'C2': '1-Non Current Assets',
#   'C3': '3-Investment in subsidiary',
#   'C4': '1-Investments',
#   'Amount': 13351},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '1-Inventories',
#   'C4': '1-Inventory in Warehouse',
#   'Amount': 1233},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '1-Inventories',
#   'C4': '1-Goods in Transit',
#   'Amount': 1265},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '1-Inventories',
#   'C4': '1-Inventory Provision',
#   'Amount': -2153},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '2-Due From Related Parties',
#   'C4': '1-Due From Related Parties',
#   'Amount': 1568},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '3-Trade Receivables',
#   'C4': '1-Trade Receivables',
#   'Amount': 156548},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '3-Trade Receivables',
#   'C4': '2-Receivable Provision',
#   'Amount': -15651},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '4-Other Receivables',
#   'C4': '1-Prepayments',
#   'Amount': 1565},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '4-Other Receivables',
#   'C4': '2-Advances',
#   'Amount': 1586},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '4-Other Receivables',
#   'C4': '3-Deposits',
#   'Amount': 15673},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '5-Other Financial Assets',
#   'C4': '1-Deposits with Bank',
#   'Amount': 15654},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '6-Cash and Cash Equivalents',
#   'C4': '1-Cash in Hand',
#   'Amount': 8641},
#  {'C1': '1-Assets',
#   'C2': '2-Current Assets',
#   'C3': '6-Cash and Cash Equivalents',
#   'C4': '2-Cash at Bank',
#   'Amount': 14565},
#  {'C1': '2-Equity',
#   'C2': '1-Equity',
#   'C3': '1-Share Capital',
#   'C4': '1-Share Capital',
#   'Amount': -15646},
#  {'C1': '2-Equity',
#   'C2': '1-Equity',
#   'C3': '2-Statutory Reserve',
#   'C4': '1-Statutory Reserve',
#   'Amount': -1567},
#  {'C1': '2-Equity',
#   'C2': '1-Equity',
#   'C3': '3-Capital Contribution ',
#   'C4': '1-Capital Contribution ',
#   'Amount': -1657},
#  {'C1': '2-Equity',
#   'C2': '1-Equity',
#   'C3': '4-Retained Earnings',
#   'C4': '1-Retained Earnings',
#   'Amount': 0},
#  {'C1': '2-Equity',
#   'C2': '1-Equity',
#   'C3': '5-Profit/Loss for the year',
#   'C4': '1-Profit/Loss for the year',
#   'Amount': -8987},
#  {'C1': '3-Liabilities',
#   'C2': '1-Non Current Liabilities',
#   'C3': "1-Employees' End of Service Indemnity",
#   'C4': '1-EOSI',
#   'Amount': -1656},
#  {'C1': '3-Liabilities',
#   'C2': '2-Current Liabilities',
#   'C3': '1-Trade Payables',
#   'C4': '1-Suppliers',
#   'Amount': -7468},
#  {'C1': '3-Liabilities',
#   'C2': '2-Current Liabilities',
#   'C3': '1-Trade Payables',
#   'C4': '2-Vendors',
#   'Amount': -15651},
#  {'C1': '3-Liabilities',
#   'C2': '2-Current Liabilities',
#   'C3': '2-Other Payables',
#   'C4': '1-Accruals',
#   'Amount': -8456},
#  {'C1': '3-Liabilities',
#   'C2': '2-Current Liabilities',
#   'C3': '2-Other Payables',
#   'C4': '2-Other Payables',
#   'Amount': -1563},
#  {'C1': '3-Liabilities',
#   'C2': '2-Current Liabilities',
#   'C3': '3-Liabilities against subject to finance lease',
#   'C4': '1-Finance Lease',
#   'Amount': -786},
#  {'C1': '3-Liabilities',
#   'C2': '2-Current Liabilities',
#   'C3': '4-Bank Borrowings',
#   'C4': '1-OverDraft',
#   'Amount': -16144},
#  {'C1': '3-Liabilities',
#   'C2': '2-Current Liabilities',
#   'C3': '4-Bank Borrowings',
#   'C4': '2-L/C',
#   'Amount': -4586},
#  {'C1': '3-Liabilities',
#   'C2': '2-Current Liabilities',
#   'C3': '4-Bank Borrowings',
#   'C4': '3-Cheque Discounting',
#   'Amount': -7465},
#  {'C1': '3-Liabilities',
#   'C2': '2-Current Liabilities',
#   'C3': '5-Due to related parties',
#   'C4': '1-Due to related parties',
#   'Amount': -15648},
#  {'C1': '4-Profit and Loss',
#   'C2': '1-Sales',
#   'C3': '1-Medical-Sals',
#   'C4': '1-Medical-Sals',
#   'Amount': -556555},
#  {'C1': '4-Profit and Loss',
#   'C2': '1-Sales',
#   'C3': '2-Equipment-Sales',
#   'C4': '1-Equipment-Sales',
#   'Amount': -315425},
#  {'C1': '4-Profit and Loss',
#   'C2': '2-Cost of Sales',
#   'C3': '1-Medical-Cost',
#   'C4': '1-Medical-Cost',
#   'Amount': 356411},
#  {'C1': '4-Profit and Loss',
#   'C2': '2-Cost of Sales',
#   'C3': '2-Equipment-Cost',
#   'C4': '1-Equipment-Cost',
#   'Amount': 245651},
#  {'C1': '4-Profit and Loss',
#   'C2': '3-Direct Expenses',
#   'C3': '1-Salaries and Related Cost - D',
#   'C4': '1-Salaries and Related Cost - D',
#   'Amount': 56841},
#  {'C1': '4-Profit and Loss',
#   'C2': '3-Direct Expenses',
#   'C3': '2-Communications - D',
#   'C4': '1-Communications - D',
#   'Amount': 1565},
#  {'C1': '4-Profit and Loss',
#   'C2': '3-Direct Expenses',
#   'C3': '3-Sales Commissionv - D',
#   'C4': '1-Sales Commissionv - D',
#   'Amount': 8746},
#  {'C1': '4-Profit and Loss',
#   'C2': '3-Direct Expenses',
#   'C3': '4-Gratuity Provision - D',
#   'C4': '1-Gratuity Provision - D',
#   'Amount': 1565},
#  {'C1': '4-Profit and Loss',
#   'C2': '3-Direct Expenses',
#   'C3': '5-Leave salaries &air tickets - D',
#   'C4': '1-Leave salaries &air tickets - D',
#   'Amount': 9658},
#  {'C1': '4-Profit and Loss',
#   'C2': '3-Direct Expenses',
#   'C3': '6-Selling and business promotion - D',
#   'C4': '1-Selling and business promotion - D',
#   'Amount': 4565},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '1-Salaries and Related Cost',
#   'C4': '1-Salaries and Related Cost',
#   'Amount': 4565},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '2-Bonus',
#   'C4': '1-Bonus',
#   'Amount': 1587},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '3-Gratuity Provision',
#   'C4': '1-Gratuity Provision',
#   'Amount': 2452},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '4-Leave Salaries and Tickets',
#   'C4': '1-Leave Salaries and Tickets',
#   'Amount': 3254},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '5-Legal, license and professional fee',
#   'C4': '1-Legal, license and professional fee',
#   'Amount': 6654},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '6-Travelling and Vehicle maintenance',
#   'C4': '1-Travelling and Vehicle maintenance',
#   'Amount': 4598},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '7-Rent',
#   'C4': '1-Rent',
#   'Amount': 6871},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '8-Office maintenance',
#   'C4': '1-Office maintenance',
#   'Amount': 9879},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '9-Bad debts',
#   'C4': '1-Bad debts',
#   'Amount': 1565},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '10-Insurance',
#   'C4': '1-Insurance',
#   'Amount': 1326},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '11-Provision for slow moving inventories',
#   'C4': '1-Provision for slow moving inventories',
#   'Amount': 2165},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '12-Communications',
#   'C4': '1-Communications',
#   'Amount': 1565},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '13-Bank charges',
#   'C4': '1-Bank charges',
#   'Amount': 3218},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '14-Printing and stationery',
#   'C4': '1-Printing and stationery',
#   'Amount': 1568},
#  {'C1': '4-Profit and Loss',
#   'C2': '4-Indirect Expenses',
#   'C3': '15-Others',
#   'C4': '1-Others',
#   'Amount': 6221},
#  {'C1': '4-Profit and Loss',
#   'C2': '5-Other Expenses',
#   'C3': '1-Other Expenses',
#   'C4': '1-Other Expenses',
#   'Amount': 6521},
#  {'C1': '4-Profit and Loss',
#   'C2': '6-Other Income',
#   'C3': '1-Other Income',
#   'C4': '1-Other Income',
#   'Amount': -1548},
#  {'C1': '4-Profit and Loss',
#   'C2': '7-Depreciation and amortiaztion',
#   'C3': '1-Depreciation and amortiaztion',
#   'C4': '1-Depreciation and amortiaztion',
#   'Amount': 3215},
#  {'C1': '4-Profit and Loss',
#   'C2': '8-Finance Cost',
#   'C3': '1-Finance Cost',
#   'C4': '1-Finance Cost',
#   'Amount': 1555}]

# %% [markdown]
# <p style="font-family:Calibri; font-size:1.75em; color:white; padding:5px 5px; text-align: left; height:50px;">
# </p>

# %% [markdown]
# <p style="font-size:2.2em; color:white; padding:25px; border-bottom: 5px solid #ffb701; background:#143157;">
#     Chart of Accounts - <span style="font-size:.75em; color: #11a1f5;"> Level </span></p>
# Read data from csv in Pandas

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:,.0f}'.format
pd.set_option('display.max_columns', 85) # set Jupeter note book to dispay 85 columns

# %% [markdown]
# <p style="font-size:1.5em; color:white; padding:5px; border-bottom: 3px solid orange; background: #3c5c75; margin: 25px 0 -7px 0;">
# Step 1 - Read CSV files </p>

# %%
###---- Read Employee master File ------------------------------------------
###---- encoding='unicode_escape' since data includes special charactor to avoid error.
df = pd.read_csv("Data/B1_Setup/CoA/CoA Level.xlsx",encoding='unicode_escape').fillna(0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [67], in <cell line: 3>()
#       1 ###---- Read Employee master File ------------------------------------------
#       2 ###---- encoding='unicode_escape' since data includes special charactor to avoid error.
# ----> 3 df = pd.read_csv("Data/B1_Setup/CoA/CoA Level.xlsx",encoding='unicode_escape').fillna(0)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/B1_Setup/CoA/CoA Level.xlsx'

# %% [markdown]
# <p style="font-size:1.5em; color:white; padding:5px; border-bottom: 3px solid orange; background: #3c5c75; margin: 25px 0 -7px 0;">
# Step 2 - Remove Duplicate Entry </p>

# %%
# remove duplicate rows and keep only the last occurrence subequently if that customer Code added
# will show because keep last record will not have 'Delete' in comment column
DataA = df.drop_duplicates(subset=['itmCode'], keep='last')
DataB = DataA.drop(DataA.loc[DataA['comment']=='Delete'].index)

# %% [markdown]
# <p style="font-size:1.5em; color:white; padding:5px; border-bottom: 3px solid orange; background: #3c5c75; margin: 25px 0 -7px 0;">
# Step 3 - Convert into Json </p>

# %%
### Convert Data into Json Dictionary (can be access by JavaScript) .........
Data = DataB.to_dict(orient="records")

# %% [markdown]
# <p style="font-family:Calibri; font-size:1.75em; color:white; padding:5px 5px; text-align: left; height:50px; border-bottom: 1px solid orange;"></p>

# %% [markdown]
# <p style="font-size:2.2em; color:white; padding:25px; border-bottom: 5px solid #ffb701; background:#143157;">
# Chart of Account  <span style="font-size:.75em; color: #11a1f5;">- Sort by Code</span></p>
# Sort Chart of Account as number and Text

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:,.0f}'.format
pd.set_option('display.max_columns', 85) # set Jupeter note book to dispay 85 columns
pd.set_option('display.max_rows', 185) # set Jupeter note book to dispay 85 columns

# %% [markdown]
# <p style="font-size:1.5em; color:white; padding:5px; border-bottom: 3px solid orange; background: #3c5c75; margin: 25px 0 -7px 0;">
# Step 1 - Read CSV files </p>

# %%
df = pd.read_excel("Data/B1_Setup/Experiment.xlsx")
stdIndex = pd.read_excel("Data/B1_Setup/Experiment.xlsx")

# %%
ptL4 = pd.pivot_table(df,index=["L1_Name","L2_Name","L3_Name","L4_Name"],values=["Amount"],aggfunc=np.sum)
ptL4 = ptL4.reset_index()
ptL4
# Out:
#             L1_Name                        L2_Name  \
# 0            Assets                 Current Assets
# 1            Assets                 Current Assets
# 2            Assets                 Current Assets
# 3            Assets                 Current Assets
# 4            Assets                 Current Assets
# 5            Assets                 Current Assets
# 6            Assets                 Current Assets
# 7            Assets                 Current Assets
# 8            Assets                 Current Assets
# 9            Assets                 Current Assets
# 10           Assets                 Current Assets
# 11           Assets                 Current Assets
# 12           Assets             Non Current Assets
# 13           Assets             Non Current Assets
# 14           Assets             Non Current Assets
# 15           Assets             Non Current Assets
# 16           Assets             Non Current Assets
# 17           Assets             Non Current Assets
# 18           Assets             Non Current Assets
# 19           Assets             Non Current Assets
# 20           Assets             Non Current Assets
# 21           Equity                         Equity
# 22           Equity                         Equity
# 23           Equity                         Equity
# 24           Equity                         Equity
# 25           Equity                         Equity
# 26      Liabilities            Current Liabilities
# 27      Liabilities            Current Liabilities
# 28      Liabilities            Current Liabilities
# 29      Liabilities            Current Liabilities
# 30      Liabilities            Current Liabilities
# 31      Liabilities            Current Liabilities
# 32      Liabilities            Current Liabilities
# 33      Liabilities            Current Liabilities
# 34      Liabilities            Current Liabilities
# 35      Liabilities        Non Current Liabilities
# 36  Profit and Loss                  Cost of Sales
# 37  Profit and Loss                  Cost of Sales
# 38  Profit and Loss  Depreciation and amortiaztion
# 39  Profit and Loss                Direct Expenses
# 40  Profit and Loss                Direct Expenses
# 41  Profit and Loss                Direct Expenses
# 42  Profit and Loss                Direct Expenses
# 43  Profit and Loss                Direct Expenses
# 44  Profit and Loss                Direct Expenses
# 45  Profit and Loss                   Finance Cost
# 46  Profit and Loss              Indirect Expenses
# 47  Profit and Loss              Indirect Expenses
# 48  Profit and Loss              Indirect Expenses
# 49  Profit and Loss              Indirect Expenses
# 50  Profit and Loss              Indirect Expenses
# 51  Profit and Loss              Indirect Expenses
# 52  Profit and Loss              Indirect Expenses
# 53  Profit and Loss              Indirect Expenses
# 54  Profit and Loss              Indirect Expenses
# 55  Profit and Loss              Indirect Expenses
# 56  Profit and Loss              Indirect Expenses
# 57  Profit and Loss              Indirect Expenses
# 58  Profit and Loss              Indirect Expenses
# 59  Profit and Loss              Indirect Expenses
# 60  Profit and Loss              Indirect Expenses
# 61  Profit and Loss                 Other Expenses
# 62  Profit and Loss                   Other Income
# 63  Profit and Loss                          Sales
# 64  Profit and Loss                          Sales
#
#                                          L3_Name  \
# 0                      Cash and Cash Equivalents
# 1                      Cash and Cash Equivalents
# 2                       Due From Related Parties
# 3                                    Inventories
# 4                                    Inventories
# 5                                    Inventories
# 6                         Other Financial Assets
# 7                              Other Receivables
# 8                              Other Receivables
# 9                              Other Receivables
# 10                             Trade Receivables
# 11                             Trade Receivables
# 12                             Intangible Assets
# 13                             Intangible Assets
# 14                      Investment in subsidiary
# 15                        Property and Equipment
# 16                        Property and Equipment
# 17                        Property and Equipment
# 18                        Property and Equipment
# 19                        Property and Equipment
# 20                        Property and Equipment
# 21                         Capital Contribution
# 22                      Profit/Loss for the year
# 23                             Retained Earnings
# 24                                 Share Capital
# 25                             Statutory Reserve
# 26                               Bank Borrowings
# 27                               Bank Borrowings
# 28                               Bank Borrowings
# 29                        Due to related parties
# 30  Liabilities against subject to finance lease
# 31                                Other Payables
# 32                                Other Payables
# 33                                Trade Payables
# 34                                Trade Payables
# 35           Employees' End of Service Indemnity
# 36                                Equipment-Cost
# 37                                  Medical-Cost
# 38                 Depreciation and amortiaztion
# 39                            Communications - D
# 40                        Gratuity Provision - D
# 41               Leave salaries &air tickets - D
# 42                 Salaries and Related Cost - D
# 43                         Sales Commissionv - D
# 44            Selling and business promotion - D
# 45                                  Finance Cost
# 46                                     Bad debts
# 47                                  Bank charges
# 48                                         Bonus
# 49                                Communications
# 50                            Gratuity Provision
# 51                                     Insurance
# 52                    Leave Salaries and Tickets
# 53           Legal, license and professional fee
# 54                            Office maintenance
# 55                                        Others
# 56                       Printing and stationery
# 57         Provision for slow moving inventories
# 58                                          Rent
# 59                     Salaries and Related Cost
# 60            Travelling and Vehicle maintenance
# 61                                Other Expenses
# 62                                  Other Income
# 63                               Equipment-Sales
# 64                                  Medical-Sals
#
#                                      L4_Name  Amount
# 0                               Cash at Bank   14565
# 1                               Cash in Hand    8641
# 2                   Due From Related Parties    1568
# 3                           Goods in Transit    1265
# 4                        Inventory Provision   -2153
# 5                     Inventory in Warehouse    1233
# 6                         Deposits with Bank   15654
# 7                                   Advances    1586
# 8                                   Deposits   15673
# 9                                Prepayments    1565
# 10                      Receivable Provision  -15651
# 11                         Trade Receivables  156548
# 12                               Copy Rights     156
# 13                                  Software     886
# 14                               Investments   13351
# 15    Buildings, Structures And Improvements    1750
# 16                  Construction In Progress    1565
# 17                    Furniture And Fixtures    3511
# 18                Land And Land Improvements    1500
# 19                   Machinery And Equipment    2250
# 20  Right Of Use Assets (Classified As PP&E)    1564
# 21                     Capital Contribution    -1657
# 22                  Profit/Loss for the year   -8987
# 23                         Retained Earnings       0
# 24                             Share Capital  -15646
# 25                         Statutory Reserve   -1567
# 26                        Cheque Discounting   -7465
# 27                                       L/C   -4586
# 28                                 OverDraft  -16144
# 29                    Due to related parties  -15648
# 30                             Finance Lease    -786
# 31                                  Accruals   -8456
# 32                            Other Payables   -1563
# 33                                 Suppliers   -7468
# 34                                   Vendors  -15651
# 35                                      EOSI   -1656
# 36                            Equipment-Cost  245651
# 37                              Medical-Cost  356411
# 38             Depreciation and amortiaztion    3215
# 39                        Communications - D    1565
# 40                    Gratuity Provision - D    1565
# 41           Leave salaries &air tickets - D    9658
# 42             Salaries and Related Cost - D   56841
# 43                     Sales Commissionv - D    8746
# 44        Selling and business promotion - D    4565
# 45                              Finance Cost    1555
# 46                                 Bad debts    1565
# 47                              Bank charges    3218
# 48                                     Bonus    1587
# 49                            Communications    1565
# 50                        Gratuity Provision    2452
# 51                                 Insurance    1326
# 52                Leave Salaries and Tickets    3254
# 53       Legal, license and professional fee    6654
# 54                        Office maintenance    9879
# 55                                    Others    6221
# 56                   Printing and stationery    1568
# 57     Provision for slow moving inventories    2165
# 58                                      Rent    6871
# 59                 Salaries and Related Cost    4565
# 60        Travelling and Vehicle maintenance    4598
# 61                            Other Expenses    6521
# 62                              Other Income   -1548
# 63                           Equipment-Sales -315425
# 64                              Medical-Sals -556555

# %%
ptL3 = pd.pivot_table(df,index=["L1_Name","L2_Name","L3_Name"],values=["Amount"],aggfunc=np.sum)
ptL3 = ptL3.reset_index()
ptL3
# Out:
#             L1_Name                        L2_Name  \
# 0            Assets                 Current Assets
# 1            Assets                 Current Assets
# 2            Assets                 Current Assets
# 3            Assets                 Current Assets
# 4            Assets                 Current Assets
# 5            Assets                 Current Assets
# 6            Assets             Non Current Assets
# 7            Assets             Non Current Assets
# 8            Assets             Non Current Assets
# 9            Equity                         Equity
# 10           Equity                         Equity
# 11           Equity                         Equity
# 12           Equity                         Equity
# 13           Equity                         Equity
# 14      Liabilities            Current Liabilities
# 15      Liabilities            Current Liabilities
# 16      Liabilities            Current Liabilities
# 17      Liabilities            Current Liabilities
# 18      Liabilities            Current Liabilities
# 19      Liabilities        Non Current Liabilities
# 20  Profit and Loss                  Cost of Sales
# 21  Profit and Loss                  Cost of Sales
# 22  Profit and Loss  Depreciation and amortiaztion
# 23  Profit and Loss                Direct Expenses
# 24  Profit and Loss                Direct Expenses
# 25  Profit and Loss                Direct Expenses
# 26  Profit and Loss                Direct Expenses
# 27  Profit and Loss                Direct Expenses
# 28  Profit and Loss                Direct Expenses
# 29  Profit and Loss                   Finance Cost
# 30  Profit and Loss              Indirect Expenses
# 31  Profit and Loss              Indirect Expenses
# 32  Profit and Loss              Indirect Expenses
# 33  Profit and Loss              Indirect Expenses
# 34  Profit and Loss              Indirect Expenses
# 35  Profit and Loss              Indirect Expenses
# 36  Profit and Loss              Indirect Expenses
# 37  Profit and Loss              Indirect Expenses
# 38  Profit and Loss              Indirect Expenses
# 39  Profit and Loss              Indirect Expenses
# 40  Profit and Loss              Indirect Expenses
# 41  Profit and Loss              Indirect Expenses
# 42  Profit and Loss              Indirect Expenses
# 43  Profit and Loss              Indirect Expenses
# 44  Profit and Loss              Indirect Expenses
# 45  Profit and Loss                 Other Expenses
# 46  Profit and Loss                   Other Income
# 47  Profit and Loss                          Sales
# 48  Profit and Loss                          Sales
#
#                                          L3_Name  Amount
# 0                      Cash and Cash Equivalents   23206
# 1                       Due From Related Parties    1568
# 2                                    Inventories     345
# 3                         Other Financial Assets   15654
# 4                              Other Receivables   18824
# 5                              Trade Receivables  140897
# 6                              Intangible Assets    1042
# 7                       Investment in subsidiary   13351
# 8                         Property and Equipment   12140
# 9                          Capital Contribution    -1657
# 10                      Profit/Loss for the year   -8987
# 11                             Retained Earnings       0
# 12                                 Share Capital  -15646
# 13                             Statutory Reserve   -1567
# 14                               Bank Borrowings  -28195
# 15                        Due to related parties  -15648
# 16  Liabilities against subject to finance lease    -786
# 17                                Other Payables  -10019
# 18                                Trade Payables  -23119
# 19           Employees' End of Service Indemnity   -1656
# 20                                Equipment-Cost  245651
# 21                                  Medical-Cost  356411
# 22                 Depreciation and amortiaztion    3215
# 23                            Communications - D    1565
# 24                        Gratuity Provision - D    1565
# 25               Leave salaries &air tickets - D    9658
# 26                 Salaries and Related Cost - D   56841
# 27                         Sales Commissionv - D    8746
# 28            Selling and business promotion - D    4565
# 29                                  Finance Cost    1555
# 30                                     Bad debts    1565
# 31                                  Bank charges    3218
# 32                                         Bonus    1587
# 33                                Communications    1565
# 34                            Gratuity Provision    2452
# 35                                     Insurance    1326
# 36                    Leave Salaries and Tickets    3254
# 37           Legal, license and professional fee    6654
# 38                            Office maintenance    9879
# 39                                        Others    6221
# 40                       Printing and stationery    1568
# 41         Provision for slow moving inventories    2165
# 42                                          Rent    6871
# 43                     Salaries and Related Cost    4565
# 44            Travelling and Vehicle maintenance    4598
# 45                                Other Expenses    6521
# 46                                  Other Income   -1548
# 47                               Equipment-Sales -315425
# 48                                  Medical-Sals -556555

# %%
ptL2 = pd.pivot_table(df,index=["L1_Name","L2_Name"],values=["Amount"],aggfunc=np.sum)
ptL2 = ptL2.reset_index()
ptL2
# Out:
#             L1_Name                        L2_Name  Amount
# 0            Assets                 Current Assets  200494
# 1            Assets             Non Current Assets   26533
# 2            Equity                         Equity  -27857
# 3       Liabilities            Current Liabilities  -77767
# 4       Liabilities        Non Current Liabilities   -1656
# 5   Profit and Loss                  Cost of Sales  602062
# 6   Profit and Loss  Depreciation and amortiaztion    3215
# 7   Profit and Loss                Direct Expenses   82940
# 8   Profit and Loss                   Finance Cost    1555
# 9   Profit and Loss              Indirect Expenses   57488
# 10  Profit and Loss                 Other Expenses    6521
# 11  Profit and Loss                   Other Income   -1548
# 12  Profit and Loss                          Sales -871980

# %%
ptL1 = pd.pivot_table(df,index=["L1_Name"],values=["Amount"],aggfunc=np.sum)
ptL1 = ptL1.reset_index()
ptL1
# Out:
#            L1_Name  Amount
# 0           Assets  227027
# 1           Equity  -27857
# 2      Liabilities  -79423
# 3  Profit and Loss -119747

# %%
#df_drop = df_Sort.drop(['L1', 'L2', 'L3', 'L4'], axis=1)
df_Sort = df.sort_values(['L1', 'L2', 'L3', 'L4'])
Selected = df_Sort[['L4_Name']]
Selected
# Out:
#                                      L4_Name
# 0                 Land And Land Improvements
# 1     Buildings, Structures And Improvements
# 2                    Machinery And Equipment
# 3                     Furniture And Fixtures
# 4   Right Of Use Assets (Classified As PP&E)
# 5                   Construction In Progress
# 6                                   Software
# 7                                Copy Rights
# 8                                Investments
# 9                     Inventory in Warehouse
# 10                          Goods in Transit
# 11                       Inventory Provision
# 12                  Due From Related Parties
# 13                         Trade Receivables
# 14                      Receivable Provision
# 15                               Prepayments
# 16                                  Advances
# 17                                  Deposits
# 18                        Deposits with Bank
# 19                              Cash in Hand
# 20                              Cash at Bank
# 21                             Share Capital
# 22                         Statutory Reserve
# 23                     Capital Contribution
# 24                         Retained Earnings
# 25                  Profit/Loss for the year
# 26                                      EOSI
# 27                                 Suppliers
# 28                                   Vendors
# 29                                  Accruals
# 30                            Other Payables
# 31                             Finance Lease
# 32                                 OverDraft
# 33                                       L/C
# 34                        Cheque Discounting
# 35                    Due to related parties
# 36                              Medical-Sals
# 37                           Equipment-Sales
# 38                              Medical-Cost
# 39                            Equipment-Cost
# 40             Salaries and Related Cost - D
# 41                        Communications - D
# 42                     Sales Commissionv - D
# 43                    Gratuity Provision - D
# 44           Leave salaries &air tickets - D
# 45        Selling and business promotion - D
# 46                 Salaries and Related Cost
# 47                                     Bonus
# 48                        Gratuity Provision
# 49                Leave Salaries and Tickets
# 50       Legal, license and professional fee
# 51        Travelling and Vehicle maintenance
# 52                                      Rent
# 53                        Office maintenance
# 54                                 Bad debts
# 55                                 Insurance
# 56     Provision for slow moving inventories
# 57                            Communications
# 58                              Bank charges
# 59                   Printing and stationery
# 60                                    Others
# 61                            Other Expenses
# 62                              Other Income
# 63             Depreciation and amortiaztion
# 64                              Finance Cost

# %%
Left_join = pd.merge(Selected, pivot,  on ='L4_Name',  how ='left')

# %%
Left_join
# Out:
#                                      L4_Name  Amount
# 0                 Land And Land Improvements    1500
# 1     Buildings, Structures And Improvements    1750
# 2                    Machinery And Equipment    2250
# 3                     Furniture And Fixtures    3511
# 4   Right Of Use Assets (Classified As PP&E)    1564
# 5                   Construction In Progress    1565
# 6                                   Software     886
# 7                                Copy Rights     156
# 8                                Investments   13351
# 9                     Inventory in Warehouse    1233
# 10                          Goods in Transit    1265
# 11                       Inventory Provision   -2153
# 12                  Due From Related Parties    1568
# 13                         Trade Receivables  156548
# 14                      Receivable Provision  -15651
# 15                               Prepayments    1565
# 16                                  Advances    1586
# 17                                  Deposits   15673
# 18                        Deposits with Bank   15654
# 19                              Cash in Hand    8641
# 20                              Cash at Bank   14565
# 21                             Share Capital  -15646
# 22                         Statutory Reserve   -1567
# 23                     Capital Contribution    -1657
# 24                         Retained Earnings -119747
# 25                  Profit/Loss for the year   -8987
# 26                                      EOSI   -1656
# 27                                 Suppliers   -7468
# 28                                   Vendors  -15651
# 29                                  Accruals   -8456
# 30                            Other Payables   -1563
# 31                             Finance Lease    -786
# 32                                 OverDraft  -16144
# 33                                       L/C   -4586
# 34                        Cheque Discounting   -7465
# 35                    Due to related parties  -15648
# 36                              Medical-Sals -556555
# 37                           Equipment-Sales -315425
# 38                              Medical-Cost  356411
# 39                            Equipment-Cost  245651
# 40             Salaries and Related Cost - D   56841
# 41                        Communications - D    1565
# 42                     Sales Commissionv - D    8746
# 43                    Gratuity Provision - D    1565
# 44           Leave salaries &air tickets - D    9658
# 45        Selling and business promotion - D    4565
# 46                 Salaries and Related Cost    4565
# 47                                     Bonus    1587
# 48                        Gratuity Provision    2452
# 49                Leave Salaries and Tickets    3254
# 50       Legal, license and professional fee    6654
# 51        Travelling and Vehicle maintenance    4598
# 52                                      Rent    6871
# 53                        Office maintenance    9879
# 54                                 Bad debts    1565
# 55                                 Insurance    1326
# 56     Provision for slow moving inventories    2165
# 57                            Communications    1565
# 58                              Bank charges    3218
# 59                   Printing and stationery    1568
# 60                                    Others    6221
# 61                            Other Expenses    6521
# 62                              Other Income   -1548
# 63             Depreciation and amortiaztion    3215
# 64                              Finance Cost    1555
